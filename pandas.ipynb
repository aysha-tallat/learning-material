# %%
import pandas as pd

# %%
#i dimension
mobile=pd.Series(['samsung','iphone','nokia'])
mobile
# Out:
# 0    samsung
# 1     iphone
# 2      nokia
# dtype: object

# %%
bag = pd.Series(['pen','paper','notebook'])
bag
# Out:
# 0         pen
# 1       paper
# 2    notebook
# dtype: object

# %%
#2 diminisional data frame
dataframe = pd.DataFrame({'electronics':mobile, 'accessories':bag})
dataframe
# Out:
#   electronics accessories
# 0     samsung         pen
# 1      iphone       paper
# 2       nokia    notebook

# %%
#importing csv file
data_csv = pd.read_csv('sales.csv')

# %%
data_csv
# Out:
#      Receipt no   Location Customer name  Session id   Sale date   Status  \
# 0          BL11    Chennai          Naga          28  06/03/2020  Ordered
# 1          BL11    Chennai        Mahesh          28  06/03/2020  Ordered
# 2          BL12  Hyderabad        Ganesh          28  06/03/2020  Ordered
# 3          BL12    Chennai         Kumar          28  06/03/2020  Ordered
# 4          BL12  Bangalore         Vijay          28  06/03/2020  Ordered
# ...         ...        ...           ...         ...         ...      ...
# 4967      BL110  Hyderabad          Naga          28  10/07/2020  Ordered
# 4968      BL110    Chennai         Rajiv          28  10/07/2020  Ordered
# 4969      BL108  Bangalore        Mahesh          28  10/07/2020  Ordered
# 4970      BL108    Chennai          Naga          28  10/07/2020  Ordered
# 4971      BL109  Hyderabad        Mahesh          28  10/07/2020  Ordered
#
#      Ordertype name  Token number   Product name Product Category  \
# ...

# %%
#exporting the file
import pandas as pd
data_csv = pd.read_csv('sales.csv')

# %%
data_csv
# Out:
#      Receipt no   Location Customer name  Session id   Sale date   Status  \
# 0          BL11    Chennai          Naga          28  06/03/2020  Ordered
# 1          BL11    Chennai        Mahesh          28  06/03/2020  Ordered
# 2          BL12  Hyderabad        Ganesh          28  06/03/2020  Ordered
# 3          BL12    Chennai         Kumar          28  06/03/2020  Ordered
# 4          BL12  Bangalore         Vijay          28  06/03/2020  Ordered
# ...         ...        ...           ...         ...         ...      ...
# 4967      BL110  Hyderabad          Naga          28  10/07/2020  Ordered
# 4968      BL110    Chennai         Rajiv          28  10/07/2020  Ordered
# 4969      BL108  Bangalore        Mahesh          28  10/07/2020  Ordered
# 4970      BL108    Chennai          Naga          28  10/07/2020  Ordered
# 4971      BL109  Hyderabad        Mahesh          28  10/07/2020  Ordered
#
#      Ordertype name  Token number   Product name Product Category  \
# ...

# %%
data_csv.to_csv('modified_data.csv')

# %%
md=pd.read_csv('modified_data.csv')

# %%
md
# Out:
#       Unnamed: 0 Receipt no   Location Customer name  Session id   Sale date  \
# 0              0       BL11    Chennai          Naga          28  06/03/2020
# 1              1       BL11    Chennai        Mahesh          28  06/03/2020
# 2              2       BL12  Hyderabad        Ganesh          28  06/03/2020
# 3              3       BL12    Chennai         Kumar          28  06/03/2020
# 4              4       BL12  Bangalore         Vijay          28  06/03/2020
# ...          ...        ...        ...           ...         ...         ...
# 4967        4967      BL110  Hyderabad          Naga          28  10/07/2020
# 4968        4968      BL110    Chennai         Rajiv          28  10/07/2020
# 4969        4969      BL108  Bangalore        Mahesh          28  10/07/2020
# 4970        4970      BL108    Chennai          Naga          28  10/07/2020
# 4971        4971      BL109  Hyderabad        Mahesh          28  10/07/2020
#
# ...

# %%
md.to_csv('modified_data.csv', index=False)

# %%
md=pd.read_csv('modified_data.csv')

# %%
md
# Out:
#       Unnamed: 0 Receipt no   Location Customer name  Session id   Sale date  \
# 0              0       BL11    Chennai          Naga          28  06/03/2020
# 1              1       BL11    Chennai        Mahesh          28  06/03/2020
# 2              2       BL12  Hyderabad        Ganesh          28  06/03/2020
# 3              3       BL12    Chennai         Kumar          28  06/03/2020
# 4              4       BL12  Bangalore         Vijay          28  06/03/2020
# ...          ...        ...        ...           ...         ...         ...
# 4967        4967      BL110  Hyderabad          Naga          28  10/07/2020
# 4968        4968      BL110    Chennai         Rajiv          28  10/07/2020
# 4969        4969      BL108  Bangalore        Mahesh          28  10/07/2020
# 4970        4970      BL108    Chennai          Naga          28  10/07/2020
# 4971        4971      BL109  Hyderabad        Mahesh          28  10/07/2020
#
# ...

# %% [markdown]
# # Data Description

# %%
#Attributes are used to describe the data ,not followed by()
#Functions are used to manipulate the data and followed by()

# %%
import pandas as pd
data_csv=pd.read_csv('sales.csv')

# %%
data_csv
# Out:
#      Receipt no   Location Customer name  Session id   Sale date   Status  \
# 0          BL11    Chennai          Naga          28  06/03/2020  Ordered
# 1          BL11    Chennai        Mahesh          28  06/03/2020  Ordered
# 2          BL12  Hyderabad        Ganesh          28  06/03/2020  Ordered
# 3          BL12    Chennai         Kumar          28  06/03/2020  Ordered
# 4          BL12  Bangalore         Vijay          28  06/03/2020  Ordered
# ...         ...        ...           ...         ...         ...      ...
# 4967      BL110  Hyderabad          Naga          28  10/07/2020  Ordered
# 4968      BL110    Chennai         Rajiv          28  10/07/2020  Ordered
# 4969      BL108  Bangalore        Mahesh          28  10/07/2020  Ordered
# 4970      BL108    Chennai          Naga          28  10/07/2020  Ordered
# 4971      BL109  Hyderabad        Mahesh          28  10/07/2020  Ordered
#
#      Ordertype name  Token number   Product name Product Category  \
# ...

# %%
data_csv.dtypes
# Out:
# Receipt no          object
# Location            object
# Customer name       object
# Session id           int64
# Sale date           object
# Status              object
# Ordertype name      object
# Token number         int64
# Product name        object
# Product Category    object
# Cost Per Unit        int64
# Selling Per Unit     int64
# Quantity             int64
# Cost Amount          int64
# Sales Amount         int64
# Profit               int64
# dtype: object

# %%
data_csv.columns
# Out:
# Index(['Receipt no', 'Location', 'Customer name', 'Session id', 'Sale date',
#        'Status', 'Ordertype name', 'Token number', 'Product name',
#        'Product Category', 'Cost Per Unit', 'Selling Per Unit', 'Quantity',
#        'Cost Amount', 'Sales Amount', 'Profit'],
#       dtype='object')

# %%
col=data_csv.columns

# %%
col
# Out:
# Index(['Receipt no', 'Location', 'Customer name', 'Session id', 'Sale date',
#        'Status', 'Ordertype name', 'Token number', 'Product name',
#        'Product Category', 'Cost Per Unit', 'Selling Per Unit', 'Quantity',
#        'Cost Amount', 'Sales Amount', 'Profit'],
#       dtype='object')

# %%
data_csv.index
# Out:
# RangeIndex(start=0, stop=4972, step=1)

# %%
data_csv.describe()
# Out:
#        Session id  Token number  Cost Per Unit  Selling Per Unit     Quantity  \
# count      4972.0        4972.0    4972.000000       4972.000000  4972.000000
# mean         28.0           0.0     668.825422        868.825422     1.038013
# std           0.0           0.0     206.379808        206.379808     0.248842
# min          28.0           0.0     100.000000        300.000000     1.000000
# 25%          28.0           0.0     400.000000        600.000000     1.000000
# 50%          28.0           0.0     700.000000        900.000000     1.000000
# 75%          28.0           0.0     900.000000       1100.000000     1.000000
# max          28.0           0.0    1000.000000       1200.000000     3.000000
#
#        Cost Amount  Sales Amount       Profit
# count  4972.000000   4972.000000  4972.000000
# mean    697.687047    905.289622   207.602574
# std     293.852867    330.276940    49.768368
# min     100.000000    300.000000   200.000000
# ...

# %%
data_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4972 entries, 0 to 4971
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Receipt no        4972 non-null   object
#  1   Location          4972 non-null   object
#  2   Customer name     4972 non-null   object
#  3   Session id        4972 non-null   int64
#  4   Sale date         4972 non-null   object
#  5   Status            4972 non-null   object
#  6   Ordertype name    4972 non-null   object
#  7   Token number      4972 non-null   int64
#  8   Product name      4972 non-null   object
#  9   Product Category  4972 non-null   object
#  10  Cost Per Unit     4972 non-null   int64
#  11  Selling Per Unit  4972 non-null   int64
#  12  Quantity          4972 non-null   int64
#  13  Cost Amount       4972 non-null   int64
#  14  Sales Amount      4972 non-null   int64
#  15  Profit            4972 non-null   int64
# dtypes: int64(8), object(8)
# ...

# %%
data_csv.mean()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_5064\547661279.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_csv.mean()
# Session id           28.000000
# Token number          0.000000
# Cost Per Unit       668.825422
# Selling Per Unit    868.825422
# Quantity              1.038013
# Cost Amount         697.687047
# Sales Amount        905.289622
# Profit              207.602574
# dtype: float64

# %%
test=pd.Series([1,2,3,4])

# %%
test.mean()
# Out:
# 2.5

# %%
data_csv['Session id']
# Out:
# 0       28
# 1       28
# 2       28
# 3       28
# 4       28
#         ..
# 4967    28
# 4968    28
# 4969    28
# 4970    28
# 4971    28
# Name: Session id, Length: 4972, dtype: int64

# %%
data_csv['Cost Amount']
# Out:
# 0       900
# 1       900
# 2       900
# 3       900
# 4       900
#        ...
# 4967    650
# 4968    400
# 4969    900
# 4970    300
# 4971    400
# Name: Cost Amount, Length: 4972, dtype: int64

# %%
data_csv['Cost Amount'].sum()
# Out:
# 3468900

# %%
data_csv['Cost Amount'].mean()
# Out:
# 697.6870474658085

# %% [markdown]
# # Data Selection

# %%
data_csv.head()
# Out:
#   Receipt no   Location Customer name  Session id   Sale date   Status  \
# 0       BL11    Chennai          Naga          28  06/03/2020  Ordered
# 1       BL11    Chennai        Mahesh          28  06/03/2020  Ordered
# 2       BL12  Hyderabad        Ganesh          28  06/03/2020  Ordered
# 3       BL12    Chennai         Kumar          28  06/03/2020  Ordered
# 4       BL12  Bangalore         Vijay          28  06/03/2020  Ordered
#
#   Ordertype name  Token number   Product name Product Category  Cost Per Unit  \
# 0        On Shop             0   Jeans  Levis      Casual Wear            900
# 1        On Shop             0   Jeans  Levis      Casual Wear            900
# 2        On Shop             0   Jeans  Levis      Casual Wear            900
# 3        On Shop             0   Jeans  Levis      Casual Wear            900
# 4        On Shop             0   Jeans  Levis      Casual Wear            900
#
#    Selling Per Unit  Quantity  Cost Amount  Sales Amount  Profit
# ...

# %%
data_csv.tail()
# Out:
#      Receipt no   Location Customer name  Session id   Sale date   Status  \
# 4967      BL110  Hyderabad          Naga          28  10/07/2020  Ordered
# 4968      BL110    Chennai         Rajiv          28  10/07/2020  Ordered
# 4969      BL108  Bangalore        Mahesh          28  10/07/2020  Ordered
# 4970      BL108    Chennai          Naga          28  10/07/2020  Ordered
# 4971      BL109  Hyderabad        Mahesh          28  10/07/2020  Ordered
#
#      Ordertype name  Token number   Product name Product Category  \
# 4967        On Shop             0          shirt           Formal
# 4968        On Shop             0         Tshirt      Semi Formal
# 4969        On Shop             0   Jeans  Levis      Casual Wear
# 4970        On Shop             0         Wallet      Accessories
# 4971        On Shop             0         Tshirt      Semi Formal
#
#       Cost Per Unit  Selling Per Unit  Quantity  Cost Amount  Sales Amount  \
# ...

# %%
data_csv.head(8)
# Out:
#   Receipt no   Location Customer name  Session id   Sale date   Status  \
# 0       BL11    Chennai          Naga          28  06/03/2020  Ordered
# 1       BL11    Chennai        Mahesh          28  06/03/2020  Ordered
# 2       BL12  Hyderabad        Ganesh          28  06/03/2020  Ordered
# 3       BL12    Chennai         Kumar          28  06/03/2020  Ordered
# 4       BL12  Bangalore         Vijay          28  06/03/2020  Ordered
# 5       BL12  Bangalore         Sunil          28  06/03/2020  Ordered
# 6       BL12    Chennai          Naga          28  06/03/2020  Ordered
# 7       BL13  Bangalore         Rajiv          28  06/03/2020  Ordered
#
#   Ordertype name  Token number   Product name Product Category  Cost Per Unit  \
# 0        On Shop             0   Jeans  Levis      Casual Wear            900
# 1        On Shop             0   Jeans  Levis      Casual Wear            900
# 2        On Shop             0   Jeans  Levis      Casual Wear            900
# ...

# %%
data_csv.tail(3)
# Out:
#      Receipt no   Location Customer name  Session id   Sale date   Status  \
# 4969      BL108  Bangalore        Mahesh          28  10/07/2020  Ordered
# 4970      BL108    Chennai          Naga          28  10/07/2020  Ordered
# 4971      BL109  Hyderabad        Mahesh          28  10/07/2020  Ordered
#
#      Ordertype name  Token number   Product name Product Category  \
# 4969        On Shop             0   Jeans  Levis      Casual Wear
# 4970        On Shop             0         Wallet      Accessories
# 4971        On Shop             0         Tshirt      Semi Formal
#
#       Cost Per Unit  Selling Per Unit  Quantity  Cost Amount  Sales Amount  \
# 4969            900              1100         1          900          1100
# 4970            300               500         1          300           500
# 4971            400               600         1          400           600
#
#       Profit
# 4969     200
# 4970     200
# 4971     200

# %% [markdown]
# # Indexing(loc) and Location(iloc)

# %%
birds=pd.Series(['crow','parrot','sparrow','eagle','hawk'], index=[0,6,8,5,9])

# %%
birds
# Out:
# 0       crow
# 6     parrot
# 8    sparrow
# 5      eagle
# 9       hawk
# dtype: object

# %%
birds.loc[5]
# Out:
# 'eagle'

# %%
birds.iloc[3]
# Out:
# 'eagle'

# %%
data_csv
# Out:
#      Receipt no   Location Customer name  Session id   Sale date   Status  \
# 0          BL11    Chennai          Naga          28  06/03/2020  Ordered
# 1          BL11    Chennai        Mahesh          28  06/03/2020  Ordered
# 2          BL12  Hyderabad        Ganesh          28  06/03/2020  Ordered
# 3          BL12    Chennai         Kumar          28  06/03/2020  Ordered
# 4          BL12  Bangalore         Vijay          28  06/03/2020  Ordered
# ...         ...        ...           ...         ...         ...      ...
# 4967      BL110  Hyderabad          Naga          28  10/07/2020  Ordered
# 4968      BL110    Chennai         Rajiv          28  10/07/2020  Ordered
# 4969      BL108  Bangalore        Mahesh          28  10/07/2020  Ordered
# 4970      BL108    Chennai          Naga          28  10/07/2020  Ordered
# 4971      BL109  Hyderabad        Mahesh          28  10/07/2020  Ordered
#
#      Ordertype name  Token number   Product name Product Category  \
# ...

# %%
data_csv.loc[3]
# Out:
# Receipt no                   BL12
# Location                  Chennai
# Customer name               Kumar
# Session id                     28
# Sale date              06/03/2020
# Status                    Ordered
# Ordertype name            On Shop
# Token number                    0
# Product name         Jeans  Levis
# Product Category      Casual Wear
# Cost Per Unit                 900
# Selling Per Unit             1100
# Quantity                        1
# Cost Amount                   900
# Sales Amount                 1100
# Profit                        200
# Name: 3, dtype: object

# %%
data_csv.iloc[3]
# Out:
# Receipt no                   BL12
# Location                  Chennai
# Customer name               Kumar
# Session id                     28
# Sale date              06/03/2020
# Status                    Ordered
# Ordertype name            On Shop
# Token number                    0
# Product name         Jeans  Levis
# Product Category      Casual Wear
# Cost Per Unit                 900
# Selling Per Unit             1100
# Quantity                        1
# Cost Amount                   900
# Sales Amount                 1100
# Profit                        200
# Name: 3, dtype: object

# %%
data_csv.loc[:3]
# Out:
#   Receipt no   Location Customer name  Session id   Sale date   Status  \
# 0       BL11    Chennai          Naga          28  06/03/2020  Ordered
# 1       BL11    Chennai        Mahesh          28  06/03/2020  Ordered
# 2       BL12  Hyderabad        Ganesh          28  06/03/2020  Ordered
# 3       BL12    Chennai         Kumar          28  06/03/2020  Ordered
#
#   Ordertype name  Token number   Product name Product Category  Cost Per Unit  \
# 0        On Shop             0   Jeans  Levis      Casual Wear            900
# 1        On Shop             0   Jeans  Levis      Casual Wear            900
# 2        On Shop             0   Jeans  Levis      Casual Wear            900
# 3        On Shop             0   Jeans  Levis      Casual Wear            900
#
#    Selling Per Unit  Quantity  Cost Amount  Sales Amount  Profit
# 0              1100         1          900          1100     200
# 1              1100         1          900          1100     200
# ...

# %%
data_csv.loc[6:9]
# Out:
#   Receipt no   Location Customer name  Session id   Sale date   Status  \
# 6       BL12    Chennai          Naga          28  06/03/2020  Ordered
# 7       BL13  Bangalore         Rajiv          28  06/03/2020  Ordered
# 8       BL13    Chennai        Mahesh          28  06/03/2020  Ordered
# 9       BL13    Chennai          Naga          28  06/03/2020  Ordered
#
#   Ordertype name  Token number   Product name Product Category  Cost Per Unit  \
# 6        On Shop             0   Jeans  Levis      Casual Wear            900
# 7        On Shop             0   Jeans  Levis      Casual Wear            900
# 8        On Shop             0   Jeans  Levis      Casual Wear            900
# 9        On Shop             0   Jeans  Denim      Casual Wear            700
#
#    Selling Per Unit  Quantity  Cost Amount  Sales Amount  Profit
# 6              1100         2         1800          2200     400
# 7              1100         1          900          1100     200
# ...

# %%
data_csv.loc[3674:3679]
# Out:
#      Receipt no   Location Customer name  Session id   Sale date   Status  \
# 3674       BL79  Bangalore         Sunil          28  09/08/2019  Ordered
# 3675       BL80  Bangalore          Naga          28  09/08/2019  Ordered
# 3676       BL80  Hyderabad        Mahesh          28  09/08/2019  Ordered
# 3677       BL81    Chennai        Ganesh          28  09/08/2019  Ordered
# 3678       BL81  Bangalore         Kumar          28  09/08/2019  Ordered
# 3679       BL82  Hyderabad         Vijay          28  09/08/2019  Ordered
#
#      Ordertype name  Token number   Product name Product Category  \
# 3674        On Shop             0          shirt           Formal
# 3675        On Shop             0    Jeans  Zara      Casual Wear
# 3676        On Shop             0   Jeans  Levis      Casual Wear
# 3677        On Shop             0    Jeans  Zara      Casual Wear
# 3678        On Shop             0    Jeans  Lega      Casual Wear
# ...

# %%
data_csv.Location     #does not work if column name has a space
# Out:
# 0         Chennai
# 1         Chennai
# 2       Hyderabad
# 3         Chennai
# 4       Bangalore
#           ...
# 4967    Hyderabad
# 4968      Chennai
# 4969    Bangalore
# 4970      Chennai
# 4971    Hyderabad
# Name: Location, Length: 4972, dtype: object

# %%
data_csv['Location']
# Out:
# 0         Chennai
# 1         Chennai
# 2       Hyderabad
# 3         Chennai
# 4       Bangalore
#           ...
# 4967    Hyderabad
# 4968      Chennai
# 4969    Bangalore
# 4970      Chennai
# 4971    Hyderabad
# Name: Location, Length: 4972, dtype: object

# %%
data_csv[data_csv['Location']=='Chennai']
# Out:
#      Receipt no Location Customer name  Session id   Sale date   Status  \
# 0          BL11  Chennai          Naga          28  06/03/2020  Ordered
# 1          BL11  Chennai        Mahesh          28  06/03/2020  Ordered
# 3          BL12  Chennai         Kumar          28  06/03/2020  Ordered
# 6          BL12  Chennai          Naga          28  06/03/2020  Ordered
# 8          BL13  Chennai        Mahesh          28  06/03/2020  Ordered
# ...         ...      ...           ...         ...         ...      ...
# 4960      BL110  Chennai        Mahesh          28  06/05/2020  Ordered
# 4962      BL108  Chennai         Kumar          28  06/05/2020  Ordered
# 4964      BL110  Chennai         Sunil          28  06/05/2020  Ordered
# 4968      BL110  Chennai         Rajiv          28  10/07/2020  Ordered
# 4970      BL108  Chennai          Naga          28  10/07/2020  Ordered
#
#      Ordertype name  Token number   Product name Product Category  \
# ...

# %%
data_csv[data_csv['Quantity']>1]
# Out:
#      Receipt no   Location Customer name  Session id   Sale date   Status  \
# 6          BL12    Chennai          Naga          28  06/03/2020  Ordered
# 12         BL14  Hyderabad         Kumar          28  06/03/2020  Ordered
# 17         BL15  Bangalore        Ganesh          28  06/03/2020  Ordered
# 44         LN15  Bangalore         Sunil          28  06/03/2020  Ordered
# 49         LN16  Hyderabad         Vijay          28  06/03/2020  Ordered
# ...         ...        ...           ...         ...         ...      ...
# 4557       BL94  Hyderabad         Kumar          28  09/12/2019  Ordered
# 4625      BL108  Bangalore          Naga          28  07/04/2020  Ordered
# 4737      BL108  Bangalore        Mahesh          28  09/04/2020  Ordered
# 4901      BL110  Hyderabad        Ganesh          28  17/04/2020  Ordered
# 4907      BL109  Hyderabad        Ganesh          28  16/04/2020  Ordered
#
#      Ordertype name  Token number   Product name Product Category  \
# ...

# %% [markdown]
# # Data Selection2

# %%
pd.crosstab(data_csv['Sale date'],data_csv['Profit'])      #comparing two columns
# Out:
# Profit      200  400  600
# Sale date
# 06/02/2019   74    0    2
# 06/02/2020   74    7    2
# 06/03/2019   74    0    2
# 06/03/2020   74    7    2
# 06/04/2019   69    0    2
# ...         ...  ...  ...
# 19/03/2020   38    4    0
# 19/04/2019   38    0    0
# 19/04/2020   38    0    0
# 19/09/2019   38    0    0
# 19/11/2019   38    0    0
#
# [122 rows x 3 columns]

# %%
pd.crosstab(data_csv['Ordertype name'],data_csv['Profit'])
# Out:
# Profit           200  400  600
# Ordertype name
# On Shop         4579   57   53
# Online Order     267    6   10

# %%
pd.crosstab(data_csv['Product name'],data_csv['Profit'])
# Out:
# Profit         200  400  600
# Product name
#  Chain         228    5    0
#  Jeans  Denim  816   16   26
#  Jeans  Lega   338    0    0
#  Jeans  Levis  862   24   21
#  Jeans  Zara   568    2   16
#  Shirt  Arrow  214    3    0
#  Shirt  PE     287    7    0
#  Tshirt        977    6    0
#  Wallet        276    0    0
#  shirt         280    0    0

# %%
#comparison more than two columns
data_csv.groupby(['Location']).sum()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_5064\3459043166.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_csv.groupby(['Location']).sum()
#            Session id  Token number  Cost Per Unit  Selling Per Unit  \
# Location
# Bangalore       46760             0        1108800           1442800
# Chennai         47740             0        1139300           1480300
# Hyderabad       44716             0        1077300           1396700
#
#            Quantity  Cost Amount  Sales Amount  Profit
# Location
# Bangalore      1736      1157900       1505100  347200
# Chennai        1768      1188400       1542000  353600
# Hyderabad      1657      1122600       1454000  331400

# %%
data_csv.groupby(['Location']).mean()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_5064\2956185930.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_csv.groupby(['Location']).mean()
#            Session id  Token number  Cost Per Unit  Selling Per Unit  \
# Location
# Bangalore        28.0           0.0     663.952096        863.952096
# Chennai          28.0           0.0     668.211144        868.211144
# Hyderabad        28.0           0.0     674.577332        874.577332
#
#            Quantity  Cost Amount  Sales Amount      Profit
# Location
# Bangalore  1.039521   693.353293    901.257485  207.904192
# Chennai    1.036950   697.008798    904.398827  207.390029
# Hyderabad  1.037570   702.943018    910.457107  207.514089

# %%
data_csv['Profit'].plot()
# Out:
# <Axes: >

# %%
data_csv['Sales Amount'].plot()
# Out:
# <Axes: >

# %%
data_csv['Profit'].hist()
# Out:
# <Axes: >

# %%
data_csv['Sales Amount'].hist()
# Out:
# <Axes: >

# %%
data_csv
# Out:
#      Receipt no   Location Customer name  Session id   Sale date   Status  \
# 0          BL11    Chennai          Naga          28  06/03/2020  Ordered
# 1          BL11    Chennai        Mahesh          28  06/03/2020  Ordered
# 2          BL12  Hyderabad        Ganesh          28  06/03/2020  Ordered
# 3          BL12    Chennai         Kumar          28  06/03/2020  Ordered
# 4          BL12  Bangalore         Vijay          28  06/03/2020  Ordered
# ...         ...        ...           ...         ...         ...      ...
# 4967      BL110  Hyderabad          Naga          28  10/07/2020  Ordered
# 4968      BL110    Chennai         Rajiv          28  10/07/2020  Ordered
# 4969      BL108  Bangalore        Mahesh          28  10/07/2020  Ordered
# 4970      BL108    Chennai          Naga          28  10/07/2020  Ordered
# 4971      BL109  Hyderabad        Mahesh          28  10/07/2020  Ordered
#
#      Ordertype name  Token number   Product name Product Category  \
# ...

# %% [markdown]
# # changing data

# %%
data_csv['Product Category'].str.lower()
# Out:
# 0       casual wear
# 1       casual wear
# 2       casual wear
# 3       casual wear
# 4       casual wear
#            ...
# 4967         formal
# 4968    semi formal
# 4969    casual wear
# 4970    accessories
# 4971    semi formal
# Name: Product Category, Length: 4972, dtype: object

# %%
data_csv['Product Category'].str.upper()
# Out:
# 0       CASUAL WEAR
# 1       CASUAL WEAR
# 2       CASUAL WEAR
# 3       CASUAL WEAR
# 4       CASUAL WEAR
#            ...
# 4967         FORMAL
# 4968    SEMI FORMAL
# 4969    CASUAL WEAR
# 4970    ACCESSORIES
# 4971    SEMI FORMAL
# Name: Product Category, Length: 4972, dtype: object

# %%
data_csv['Product Category'].str.capitalize()
# Out:
# 0       Casual wear
# 1       Casual wear
# 2       Casual wear
# 3       Casual wear
# 4       Casual wear
#            ...
# 4967         Formal
# 4968    Semi formal
# 4969    Casual wear
# 4970    Accessories
# 4971    Semi formal
# Name: Product Category, Length: 4972, dtype: object

# %% [markdown]
# # Adding and Removing Data

# %%
phone=pd.read_csv('phone.csv')

# %%
phone
# Out:
#        Make Colour  Memory(kb)  Sim Card      Price
# 0   Samsung  Black        2598         3   $230.00
# 1    Iphone   Blue        5981         2   $568.00
# 2     Nokia  White        5638         5   $264.00
# 3   Samsung  White        1900         3   $370.00
# 4  Motorola   Grey        3568         2   $400.00
# 5   Samsung   Blue        4782         4   $290.00
# 6     Nokia    Red        4790         1   $380.00
# 7   Samsung  Black        6000         3   $275.00
# 8    Iphone  White        3129         2   $355.00

# %%
phm=pd.read_csv('ph_missing.csv')

# %%
phm
# Out:
#        Make Colour  Memory(kb)  Sim Card     Price
# 0   Samsung  Black      2598.0       3.0  $230.00
# 1    Iphone   Blue         NaN       2.0  $568.00
# 2     Nokia    NaN      5638.0       5.0  $264.00
# 3   Samsung  White      1900.0       NaN  $370.00
# 4  Motorola   Grey      3568.0       2.0  $400.00
# 5       NaN   Blue      4782.0       4.0  $290.00
# 6     Nokia    Red         NaN       1.0  $380.00
# 7   Samsung  Black      6000.0       3.0  $275.00
# 8    Iphone  White      3129.0       2.0  $355.00

# %%
phone['Price'].str.replace('$','')
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_14644\1113342808.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   phone['Price'].str.replace('$','')
# 0     230.00
# 1     568.00
# 2     264.00
# 3     370.00
# 4     400.00
# 5     290.00
# 6     380.00
# 7     275.00
# 8     355.00
# Name: Price, dtype: object

# %%
phone['Price']astype(float)
# Out:
#   Cell In[15], line 1
#     phone['Price']astype(float)
#                   ^
# SyntaxError: invalid syntax

# %%
phone
# Out:
#        Make Colour  Memory(kb)  Sim Card      Price
# 0   Samsung  Black        2598         3   $230.00
# 1    Iphone   Blue        5981         2   $568.00
# 2     Nokia  White        5638         5   $264.00
# 3   Samsung  White        1900         3   $370.00
# 4  Motorola   Grey        3568         2   $400.00
# 5   Samsung   Blue        4782         4   $290.00
# 6     Nokia    Red        4790         1   $380.00
# 7   Samsung  Black        6000         3   $275.00
# 8    Iphone  White        3129         2   $355.00

# %%
phm['Memory(kb)'].mean()
# Out:
# 3945.0

# %%
phm['Memory(kb)'].fillna(phm['Memory(kb)'].mean(),inplace=True)

# %%
phm
# Out:
#        Make Colour  Memory(kb)  Sim Card     Price
# 0   Samsung  Black      2598.0       3.0  $230.00
# 1    Iphone   Blue      3945.0       2.0  $568.00
# 2     Nokia    NaN      5638.0       5.0  $264.00
# 3   Samsung  White      1900.0       NaN  $370.00
# 4  Motorola   Grey      3568.0       2.0  $400.00
# 5       NaN   Blue      4782.0       4.0  $290.00
# 6     Nokia    Red      3945.0       1.0  $380.00
# 7   Samsung  Black      6000.0       3.0  $275.00
# 8    Iphone  White      3129.0       2.0  $355.00
